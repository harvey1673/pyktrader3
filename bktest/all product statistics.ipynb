# %%
import warnings
import sys
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.dates as dates
import matplotlib.pyplot as plt
import datetime
import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, plot, iplot

init_notebook_mode(connected=True)
sys.path.append("C:/dev/pycmqlib3/")
sys.path.append("C:/dev/pycmqlib3/misc_scripts/")
warnings.filterwarnings('ignore')
import misc
import data_handler as dh
import plotly_examples
import backtest
import alphalens as al
# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
ferrous_products_mkts = ['rb', 'hc', 'i', 'j', 'jm']
ferrous_mixed_mkts = ['ru', 'FG', 'ZC', 'SM', "SF"] # 'UR', 
base_metal_mkts = ['cu', 'al', 'zn', 'pb', 'ni', 'sn'] # , 'ss'
precious_metal_mkts = ['au', 'ag']
ind_metal_mkts = ferrous_products_mkts + ferrous_mixed_mkts + base_metal_mkts
petro_chem_mkts = ['l', 'pp', 'v', 'TA', 'MA', 'bu', 'sc', 'fu', ] # 'pg', 'eb', 'eg', 'lu'  
ind_all_mkts = ind_metal_mkts + petro_chem_mkts
ags_oil_mkts = ['m', 'RM', 'y', 'p', 'OI', 'a', 'c', 'cs'] #, 'b']
ags_soft_mkts = ['CF', 'SR', 'jd', 'AP'] # , 'sp', 'rr', 'SA' , 'CJ'
ags_all_mkts = ags_oil_mkts + ags_soft_mkts
eq_fut_mkts = ['IF', 'IH', 'IC']
bond_fut_mkts = ['T', 'TF'] # 'TS'
fin_all_mkts = eq_fut_mkts + bond_fut_mkts
commod_all_mkts = ind_all_mkts + ags_all_mkts + precious_metal_mkts
all_markets = commod_all_mkts + fin_all_mkts

# %%
field_list = ['open', 'high', 'low', 'close', 'volume', 'openInterest', 'contract', 'shift']

start_date = datetime.date(2014,7,1)
end_date = datetime.date(2020,7,10)

sim_products = all_markets
need_shift = 2
freq = 'd'
delim = '-'

args = {'n': 1, 'roll_rule': '-35b', 'freq': freq, 'need_shift': need_shift}
ferrous_products_args = args
ferro_mixed_mkt_args = args
base_args = {'n': 1, 'roll_rule': '-30b', 'freq': freq, 'need_shift': need_shift}
eq_args = {'n': 1, 'roll_rule': '-1b', 'freq': freq, 'need_shift': need_shift}
bond_args = {'n': 1, 'roll_rule': '-30b', 'freq': freq, 'need_shift': need_shift}
precious_args = {'n': 1, 'roll_rule': '-25b', 'freq': freq, 'need_shift': need_shift}

df_list = []
for idx, asset in enumerate(sim_products):
    use_args = args
    if asset in eq_fut_mkts:
        use_args = eq_args
    elif asset in ['cu', 'al', 'zn', 'pb', 'sn']:
        use_args = base_args
    elif asset in bond_fut_mkts:
        use_args = bond_args
    elif asset in precious_metal_mkts:
        use_args = precious_args
    use_args['start_date'] = max(backtest.sim_start_dict[asset], start_date)
    use_args['end_date'] = end_date
    print("loading mkt = %s, args = %s" % (asset, use_args))
    df = misc.nearby(asset, **use_args)
    if freq == 'm':
        df = misc.cleanup_mindata(df, asset)
    if (idx == 0) and (freq == 'm'):
        df_list.append(df[['date', 'min_id']])    
    xdf = df[field_list]
    xdf.columns = [(asset, col) for col in xdf.columns]
    df_list.append(xdf)

all_df = pd.concat(df_list, axis = 1, sort = False)
# Out:
# loading mkt = rb, args = {'n': 1, 'roll_rule': '-35b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2014, 7, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = hc, args = {'n': 1, 'roll_rule': '-35b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2014, 7, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = i, args = {'n': 1, 'roll_rule': '-35b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2014, 7, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = j, args = {'n': 1, 'roll_rule': '-35b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2014, 7, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = jm, args = {'n': 1, 'roll_rule': '-35b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2014, 7, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = ru, args = {'n': 1, 'roll_rule': '-35b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2014, 7, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = FG, args = {'n': 1, 'roll_rule': '-35b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2014, 7, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = ZC, args = {'n': 1, 'roll_rule': '-35b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2015, 12, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = SM, args = {'n': 1, 'roll_rule': '-35b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2016, 10, 10), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = SF, args = {'n': 1, 'roll_rule': '-35b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2016, 10, 10), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = cu, args = {'n': 1, 'roll_rule': '-30b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2014, 7, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = al, args = {'n': 1, 'roll_rule': '-30b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2014, 7, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = zn, args = {'n': 1, 'roll_rule': '-30b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2014, 7, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = pb, args = {'n': 1, 'roll_rule': '-30b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2014, 7, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = ni, args = {'n': 1, 'roll_rule': '-35b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2015, 6, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = sn, args = {'n': 1, 'roll_rule': '-30b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2015, 6, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = l, args = {'n': 1, 'roll_rule': '-35b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2014, 7, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = pp, args = {'n': 1, 'roll_rule': '-35b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2014, 7, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = v, args = {'n': 1, 'roll_rule': '-35b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2014, 7, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = TA, args = {'n': 1, 'roll_rule': '-35b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2014, 7, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = MA, args = {'n': 1, 'roll_rule': '-35b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2015, 7, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = bu, args = {'n': 1, 'roll_rule': '-35b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2015, 11, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = sc, args = {'n': 1, 'roll_rule': '-35b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2018, 8, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = fu, args = {'n': 1, 'roll_rule': '-35b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2018, 7, 16), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = m, args = {'n': 1, 'roll_rule': '-35b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2014, 7, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = RM, args = {'n': 1, 'roll_rule': '-35b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2014, 7, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = y, args = {'n': 1, 'roll_rule': '-35b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2014, 7, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = p, args = {'n': 1, 'roll_rule': '-35b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2014, 7, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = OI, args = {'n': 1, 'roll_rule': '-35b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2014, 7, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = a, args = {'n': 1, 'roll_rule': '-35b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2014, 7, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = c, args = {'n': 1, 'roll_rule': '-35b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2014, 7, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = cs, args = {'n': 1, 'roll_rule': '-35b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2015, 3, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = CF, args = {'n': 1, 'roll_rule': '-35b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2014, 7, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = SR, args = {'n': 1, 'roll_rule': '-35b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2014, 7, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = jd, args = {'n': 1, 'roll_rule': '-35b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2014, 7, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = AP, args = {'n': 1, 'roll_rule': '-35b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2018, 4, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = au, args = {'n': 1, 'roll_rule': '-25b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2014, 7, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = ag, args = {'n': 1, 'roll_rule': '-25b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2014, 7, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = IF, args = {'n': 1, 'roll_rule': '-1b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2014, 7, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = IH, args = {'n': 1, 'roll_rule': '-1b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2015, 5, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = IC, args = {'n': 1, 'roll_rule': '-1b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2015, 5, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = T, args = {'n': 1, 'roll_rule': '-30b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2015, 6, 1), 'end_date': datetime.date(2020, 7, 10)}
# loading mkt = TF, args = {'n': 1, 'roll_rule': '-30b', 'freq': 'd', 'need_shift': 2, 'start_date': datetime.date(2014, 7, 1), 'end_date': datetime.date(2020, 7, 10)}

# %%
product_list = all_markets
if freq == 'm':
    prod_fields = ['date', 'min_id'] + [(asset, field) for field in field_list for asset in product_list]
    df = all_df[prod_fields].copy()

    bar_freq = '85m'

    split_dict = {'s1': [300, 2100],
                 's2': [300, 1500, 2100],
                 's3': [300, 1500, 1930, 2100],
                 's4': [300, 1500, 1630, 1930, 2100],}
    if 's' in bar_freq:
        df = dh.day_split1(df, split_dict[bar_freq])
    else:
        df = dh.conv_ohlc_freq1(df, bar_freq) 
else:
    prod_fields = [(asset, field) for field in field_list for asset in product_list]
    df = all_df[prod_fields].copy()
for asset in product_list:
    df[(asset, 'lr')] = np.log(df[(asset, 'close')].astype('float'))\
                          -np.log(df[(asset, 'close')].shift(1))  
log_ret = df[[(asset, 'lr') for asset in product_list]].copy()
print(log_ret[-5:])
# Out:
#             (rb, lr)  (hc, lr)   (i, lr)   (j, lr)  (jm, lr)  (ru, lr)  \
# 2020-07-06 -0.000276 -0.000277  0.006014 -0.001872 -0.001679  0.011851
# 2020-07-07  0.004413  0.006635  0.021747  0.005073 -0.003366 -0.007094
# 2020-07-08  0.017999  0.018835  0.027011  0.016900  0.008393  0.010857
# 2020-07-09  0.006734  0.005394  0.001268 -0.001310  0.017810  0.004216
# 2020-07-10 -0.009440 -0.005664  0.002532 -0.016123 -0.017392 -0.018877
#
#             (FG, lr)  (ZC, lr)  (SM, lr)  (SF, lr)  ...  (SR, lr)  (jd, lr)  \
# 2020-07-06  0.008687 -0.011408  0.017737  0.017410  ...  0.005456  0.004063
# 2020-07-07  0.015842  0.003579 -0.013734 -0.004069  ... -0.000778  0.010086
# 2020-07-08  0.001963 -0.001430  0.020381 -0.012652  ...  0.021167 -0.000753
# 2020-07-09  0.008461 -0.004303 -0.001507 -0.006906  ... -0.001524 -0.021572
# 2020-07-10 -0.000648  0.000718  0.005114 -0.010449  ... -0.006313  0.001026
#
#             (AP, lr)  (au, lr)  (ag, lr)  (IF, lr)  (IH, lr)  (IC, lr)  \
# 2020-07-06  0.000370 -0.002199  0.000685  0.071576  0.086863  0.043832
# 2020-07-07 -0.006305  0.001650  0.001825 -0.004616 -0.017773  0.014986
# 2020-07-08  0.005442  0.005083  0.009528  0.010009  0.010714  0.017870
# 2020-07-09  0.007741  0.006194  0.023872  0.015883  0.002631  0.029011
# 2020-07-10 -0.037411 -0.007338 -0.019141 -0.018955 -0.027771 -0.002747
#
#              (T, lr)  (TF, lr)
# 2020-07-06 -0.010357 -0.010443
# 2020-07-07  0.000354  0.001044
# 2020-07-08 -0.004405 -0.003036
# 2020-07-09 -0.001015 -0.001297
# 2020-07-10  0.001371  0.001945
#
# [5 rows x 43 columns]

# %%
start_date = datetime.date(2017,1,1)
end_date = datetime.date(2020,7,10)
log_ret = df[[(asset, 'lr') for asset in product_list]].copy()
log_ret.columns = product_list
selected_ret = log_ret[(log_ret.index >= start_date) & (log_ret.index <= end_date)].copy()

stats = ['mean', 'median', 'std', 'skew', 'kurt']
stats_df = pd.DataFrame(0, index = product_list, columns = stats)

for asset in product_list:
    for func in stats:        
        stats_df[func].loc[asset] = getattr(selected_ret[asset], func)()

print(stats_df)

print(selected_ret.corr())
# Out:
#         mean    median       std      skew       kurt
# rb  0.001043  0.001081  0.015525 -0.364604   2.912296
# hc  0.000705  0.000815  0.014967 -0.451322   3.207996
# i   0.001281  0.001104  0.021319 -0.075854   0.958822
# j   0.000767  0.001002  0.020495 -0.286044   1.677116
# jm  0.000602  0.000973  0.018809 -0.261771   2.617953
# ru -0.001266 -0.000426  0.017590 -0.628481   3.248586
# FG  0.000568  0.000688  0.012017 -0.051896   4.182972
# ZC  0.000590  0.000158  0.011435  0.061404   1.692298
# SM  0.000457  0.000000  0.014718  0.050441   3.167991
# SF  0.000342  0.000390  0.013535  0.075230   4.004065
# cu  0.000056  0.000210  0.009953 -0.899055   6.893127
# al  0.000041  0.000323  0.009127 -0.242621   4.893156
# zn  0.000126  0.000000  0.012603 -0.170487   1.374773
# pb  0.000120  0.000273  0.011540 -0.310654   3.084594
# ni  0.000210  0.001159  0.015481  0.027521   1.636824
# sn -0.000137  0.000000  0.010522 -0.526983  10.094866
# l  -0.000208  0.000000  0.011524 -0.046126   4.034986
# pp  0.000036  0.000108  0.013005 -0.081479   2.898533
# v   0.000190  0.000000  0.012204 -0.201757   2.129918
# TA -0.000295  0.000000  0.013334  0.053316   2.880046
# MA -0.000698 -0.000305  0.015965 -0.146669   1.022953
# bu -0.000289  0.000700  0.018972 -0.452481   4.071416
# sc -0.001273 -0.000558  0.022842 -0.323128   3.396740
# fu -0.000805  0.000000  0.023206 -0.563737   2.026609
# m   0.000194  0.000000  0.010399  0.315195   2.406772
# RM  0.000110  0.000000  0.012189  0.194465   2.315966
# y  -0.000506  0.000000  0.009034 -0.723937   3.838558
# p  -0.000381  0.000000  0.011542 -0.184452   1.675916
# OI -0.000088  0.000000  0.009023 -0.955281   5.676127
# a  -0.000145  0.000000  0.009344  0.516561   3.317604
# c   0.000121  0.000000  0.005970 -0.121644   1.682065
# cs  0.000131  0.000000  0.006854  0.209367   2.323833
# CF -0.000632 -0.000325  0.011375 -0.588517   3.569535
# SR -0.000260  0.000000  0.008607  0.010770   2.171618
# jd -0.000194  0.000000  0.012861  0.010932   3.055227
# AP  0.000782 -0.000045  0.016648  0.204144   2.354565
# au  0.000358  0.000345  0.007550  0.148080   7.559236
# ag -0.000063  0.000000  0.012882 -0.565722  10.952968
# IF  0.000572  0.000607  0.013361 -0.629188   8.352722
# IH  0.000518  0.000580  0.013202 -0.331516   8.500581
# IC  0.000484  0.000759  0.015385 -0.980080   6.763612
# T   0.000074  0.000052  0.002528  0.056818   1.785075
# TF  0.000049  0.000052  0.001584 -0.220573   4.991794
#           rb        hc         i         j        jm        ru        FG  \
# rb  1.000000  0.921339  0.706430  0.682816  0.573956  0.456220  0.423346
# hc  0.921339  1.000000  0.666710  0.640797  0.537123  0.455640  0.414673
# i   0.706430  0.666710  1.000000  0.594921  0.558798  0.462414  0.425790
# j   0.682816  0.640797  0.594921  1.000000  0.803030  0.411047  0.425488
# jm  0.573956  0.537123  0.558798  0.803030  1.000000  0.414535  0.407023
# ru  0.456220  0.455640  0.462414  0.411047  0.414535  1.000000  0.377389
# FG  0.423346  0.414673  0.425790  0.425488  0.407023  0.377389  1.000000
# ZC  0.349356  0.343058  0.344497  0.476747  0.507316  0.282109  0.283142
# SM  0.378549  0.346684  0.366258  0.372959  0.343042  0.197762  0.242372
# SF  0.261066  0.248969  0.302424  0.309759  0.286858  0.175686  0.213295
# cu  0.404918  0.444934  0.382720  0.351383  0.313329  0.469590  0.345240
# al  0.280841  0.312906  0.239785  0.275527  0.295681  0.321275  0.232026
# zn  0.375430  0.409875  0.343501  0.357659  0.340298  0.407107  0.272688
# pb  0.308772  0.337302  0.254475  0.308969  0.328667  0.315931  0.213522
# ni  0.319070  0.341553  0.354906  0.305001  0.297786  0.418993  0.279443
# sn  0.268311  0.291582  0.229407  0.239234  0.223257  0.322812  0.244041
# l   0.332667  0.341847  0.296954  0.308837  0.323895  0.452563  0.277658
# pp  0.386894  0.385303  0.362041  0.374780  0.373566  0.466325  0.285398
# v   0.378780  0.371856  0.333395  0.382586  0.370994  0.388589  0.303206
# TA  0.255078  0.259903  0.276188  0.266828  0.225420  0.366779  0.220002
# MA  0.395023  0.375839  0.348761  0.385086  0.368442  0.465530  0.312919
# bu  0.316328  0.313341  0.303633  0.331416  0.349195  0.433967  0.342861
# sc  0.171984  0.170378  0.225106  0.195282  0.173390  0.399918  0.203072
# fu  0.252116  0.250428  0.246457  0.232957  0.231426  0.426025  0.256981
# m   0.103395  0.085040  0.109634  0.091584  0.106717  0.122034  0.120203
# RM  0.128195  0.118784  0.130376  0.112449  0.121314  0.165343  0.158299
# y   0.229081  0.226351  0.215513  0.205185  0.218887  0.383929  0.188924
# p   0.209832  0.192870  0.217208  0.186135  0.196778  0.356299  0.191836
# OI  0.211640  0.217145  0.192315  0.209855  0.220363  0.351210  0.213463
# a   0.073945  0.059158  0.088566  0.062151  0.131497  0.103498  0.079835
# c   0.023488  0.030007  0.054894  0.033085  0.060581  0.109466  0.090139
# cs  0.048407  0.057376  0.052812  0.054242  0.077448  0.117646  0.100994
# CF  0.188227  0.194075  0.168829  0.179946  0.159192  0.374947  0.198550
# SR  0.168058  0.171100  0.170902  0.153637  0.169910  0.300002  0.139852
# jd  0.136432  0.147587  0.145549  0.114339  0.133646  0.173252  0.045415
# AP  0.191558  0.163615  0.136767  0.232357  0.199621  0.114850  0.198508
# au -0.028130 -0.005657 -0.030294 -0.048435 -0.012149  0.022082 -0.048699
# ag  0.063581  0.093414  0.058381  0.044441  0.049547  0.187148  0.064772
# IF  0.246942  0.266035  0.190940  0.223608  0.175189  0.298545  0.267378
# IH  0.235891  0.245038  0.174007  0.224731  0.173203  0.283955  0.256872
# IC  0.239307  0.264737  0.198092  0.191118  0.154637  0.281842  0.226020
# T  -0.147765 -0.141593 -0.123856 -0.134219 -0.117807 -0.134532 -0.080605
# TF -0.128287 -0.122087 -0.096008 -0.112955 -0.105413 -0.125433 -0.065070
#
#           ZC        SM        SF  ...        SR        jd        AP        au  \
# rb  0.349356  0.378549  0.261066  ...  0.168058  0.136432  0.191558 -0.028130
# hc  0.343058  0.346684  0.248969  ...  0.171100  0.147587  0.163615 -0.005657
# i   0.344497  0.366258  0.302424  ...  0.170902  0.145549  0.136767 -0.030294
# j   0.476747  0.372959  0.309759  ...  0.153637  0.114339  0.232357 -0.048435
# jm  0.507316  0.343042  0.286858  ...  0.169910  0.133646  0.199621 -0.012149
# ru  0.282109  0.197762  0.175686  ...  0.300002  0.173252  0.114850  0.022082
# FG  0.283142  0.242372  0.213295  ...  0.139852  0.045415  0.198508 -0.048699
# ZC  1.000000  0.272043  0.195447  ...  0.087466  0.100617  0.049915  0.063000
# SM  0.272043  1.000000  0.541511  ...  0.052902  0.016613  0.113707 -0.008748
# SF  0.195447  0.541511  1.000000  ...  0.090010  0.080413  0.081198 -0.046820
# cu  0.236574  0.172826  0.173727  ...  0.189687  0.137457  0.171566 -0.004184
# al  0.211972  0.105374  0.079981  ...  0.146338  0.097982  0.122438  0.016572
# zn  0.258218  0.182419  0.162289  ...  0.125161  0.091989  0.139884  0.006529
# pb  0.237107  0.112794  0.083439  ...  0.063544  0.144873  0.145523  0.014024
# ni  0.176470  0.175612  0.170159  ...  0.150867  0.084456  0.146728  0.027896
# sn  0.191663  0.111684  0.109516  ...  0.108751  0.053605  0.078699  0.066557
# l   0.241306  0.182525  0.166034  ...  0.207997  0.117706  0.059905  0.062523
# pp  0.280741  0.242407  0.191569  ...  0.182412  0.140598  0.097338  0.025982
# v   0.294475  0.219900  0.159055  ...  0.136524  0.091116  0.093751 -0.002745
# TA  0.196058  0.132649  0.127091  ...  0.184511  0.083173  0.081129  0.032962
# MA  0.272341  0.228312  0.188690  ...  0.199801  0.093254  0.107082  0.022493
# bu  0.260936  0.121353  0.148534  ...  0.232709  0.146753  0.160146  0.033468
# sc  0.237884  0.003058  0.044183  ...  0.214828  0.142068  0.058460  0.029658
# fu  0.194801  0.038358  0.054913  ...  0.252041  0.148382  0.102611 -0.024843
# m  -0.001325  0.056447  0.064542  ...  0.155275  0.147526  0.061882  0.006338
# RM  0.009261  0.066562  0.059642  ...  0.199168  0.155008  0.096308  0.026239
# y   0.118198  0.032103  0.054812  ...  0.309603  0.129987  0.050206  0.054068
# p   0.118131  0.041354  0.068217  ...  0.287297  0.076589 -0.004633  0.067414
# OI  0.113505  0.026410  0.039882  ...  0.284836  0.117657  0.063316  0.064123
# a   0.042893  0.072939  0.045145  ...  0.115134  0.035602  0.047201  0.003741
# c   0.047939  0.042914  0.087265  ...  0.106466  0.074951  0.037655  0.010253
# cs  0.042050  0.019381  0.091493  ...  0.104952  0.097117  0.073369 -0.001757
# CF  0.125634  0.070227  0.101100  ...  0.329149  0.110827  0.174468 -0.090550
# SR  0.087466  0.052902  0.090010  ...  1.000000  0.124017  0.048878 -0.001346
# jd  0.100617  0.016613  0.080413  ...  0.124017  1.000000  0.170951  0.043154
# AP  0.049915  0.113707  0.081198  ...  0.048878  0.170951  1.000000 -0.103666
# au  0.063000 -0.008748 -0.046820  ... -0.001346  0.043154 -0.103666  1.000000
# ag  0.106509  0.017688 -0.002057  ...  0.046616  0.107515 -0.030922  0.751816
# IF  0.095741  0.083126  0.107284  ...  0.211163  0.081338  0.159777 -0.078530
# IH  0.113781  0.093039  0.116441  ...  0.206078  0.063279  0.169145 -0.077757
# IC  0.061911  0.066180  0.070697  ...  0.196808  0.071939  0.116697 -0.078519
# T  -0.026829  0.004677 -0.003332  ... -0.109837 -0.008241 -0.052939  0.195602
# TF -0.023273 -0.013306 -0.000052  ... -0.103377  0.015238 -0.054183  0.179717
#
#           ag        IF        IH        IC         T        TF
# rb  0.063581  0.246942  0.235891  0.239307 -0.147765 -0.128287
# hc  0.093414  0.266035  0.245038  0.264737 -0.141593 -0.122087
# i   0.058381  0.190940  0.174007  0.198092 -0.123856 -0.096008
# j   0.044441  0.223608  0.224731  0.191118 -0.134219 -0.112955
# jm  0.049547  0.175189  0.173203  0.154637 -0.117807 -0.105413
# ru  0.187148  0.298545  0.283955  0.281842 -0.134532 -0.125433
# FG  0.064772  0.267378  0.256872  0.226020 -0.080605 -0.065070
# ZC  0.106509  0.095741  0.113781  0.061911 -0.026829 -0.023273
# SM  0.017688  0.083126  0.093039  0.066180  0.004677 -0.013306
# SF -0.002057  0.107284  0.116441  0.070697 -0.003332 -0.000052
# cu  0.283847  0.443981  0.438258  0.366847 -0.152139 -0.149037
# al  0.185777  0.256682  0.242509  0.251865 -0.151984 -0.144379
# zn  0.209363  0.306305  0.303647  0.252998 -0.138342 -0.138123
# pb  0.175751  0.214387  0.210378  0.180860 -0.099264 -0.105239
# ni  0.207110  0.316831  0.305114  0.268067 -0.178558 -0.178903
# sn  0.308285  0.282054  0.287212  0.231197 -0.090176 -0.122282
# l   0.229954  0.269596  0.257520  0.246396 -0.086416 -0.109814
# pp  0.202392  0.270556  0.265976  0.236346 -0.088692 -0.104075
# v   0.102794  0.199964  0.187114  0.209117 -0.100402 -0.101833
# TA  0.209882  0.208022  0.197738  0.204908 -0.054425 -0.081614
# MA  0.146077  0.210913  0.210369  0.189968 -0.092217 -0.094169
# bu  0.235223  0.316820  0.312416  0.274193 -0.106191 -0.121294
# sc  0.238871  0.251357  0.235308  0.253795 -0.075761 -0.068111
# fu  0.185759  0.305327  0.294370  0.295728 -0.124128 -0.118663
# m   0.027943 -0.021595 -0.024658 -0.005558 -0.056604 -0.058780
# RM  0.050719  0.008963 -0.000902  0.026234 -0.069444 -0.056904
# y   0.158158  0.221972  0.214160  0.225487 -0.146593 -0.130194
# p   0.145209  0.173373  0.164529  0.182259 -0.110321 -0.103245
# OI  0.151436  0.197463  0.190804  0.204537 -0.148754 -0.114892
# a  -0.046034  0.006617  0.003241  0.004426 -0.046695 -0.046376
# c   0.004766 -0.041525 -0.039882 -0.041232 -0.001649 -0.006694
# cs  0.016936  0.017078  0.015352  0.005777 -0.013201 -0.004423
# CF  0.106608  0.348946  0.326774  0.325807 -0.098824 -0.105093
# SR  0.046616  0.211163  0.206078  0.196808 -0.109837 -0.103377
# jd  0.107515  0.081338  0.063279  0.071939 -0.008241  0.015238
# AP -0.030922  0.159777  0.169145  0.116697 -0.052939 -0.054183
# au  0.751816 -0.078530 -0.077757 -0.078519  0.195602  0.179717
# ag  1.000000  0.138314  0.130165  0.118087  0.069907  0.054859
# IF  0.138314  1.000000  0.953217  0.852006 -0.273033 -0.262476
# IH  0.130165  0.953217  1.000000  0.693922 -0.286242 -0.283438
# IC  0.118087  0.852006  0.693922  1.000000 -0.216105 -0.192329
# T   0.069907 -0.273033 -0.286242 -0.216105  1.000000  0.923752
# TF  0.054859 -0.262476 -0.283438 -0.192329  0.923752  1.000000
#
# [43 rows x 43 columns]
