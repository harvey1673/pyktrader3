# %%
import warnings
import sys
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.dates as dates
import matplotlib.pyplot as plt
import datetime
sys.path.append("C:/dev/pycmqlib3/")
sys.path.append("C:/dev/pycmqlib3/misc_scripts/")
warnings.filterwarnings('ignore')
import misc
import data_handler as dh
import backtest

# %%
sig = np.array([ i * 0.01 for i in range(-400, 400, 2)])
param = 2.0
for resp in ['linear', 'semilinear', 'reverting', 'absorbing', 'sigmoid', 'band', 'buffer']:
    out_sig = dh.response_curve(sig, response = resp, param = param)
    plt.plot(sig, out_sig)
    plt.ylabel(resp)
    plt.show()
out_sig = [x * np.exp(-x*x/2)*1.414/0.89 for x in sig]
plt.plot(sig, out_sig)
plt.ylabel("adhoc")
plt.show()
